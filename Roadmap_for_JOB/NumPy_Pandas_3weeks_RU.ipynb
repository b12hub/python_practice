# %% [markdown]
# # ⚔️ NumPy & Pandas Killer — 5-недельное путешествие к мастерству
#
# Привет, Алекс (NotHero)! 👋
#
# Добро пожаловать в обновлённый, вдохновляющий и интерактивный тренировочный ноутбук. Он создан, чтобы превратить ежедневную практику в чёткий путь с вызовами, наградами и ощущением прогресса.
#
# Что внутри:
# - 5 недель плотной практики: EASY / MEDIUM / HARD / CONCEPT.
# - Задания на NumPy и Pandas с чистыми структурами и подсказками.
# - Пустые ячейки кода/ответа сразу под каждым заданием — можно моментально приступать.
#
# К концу этого пути вы:
# - Укрепите основы NumPy: массивы, индексация, векторизация, трансформации.
# - Освоите Pandas на уровне профессионального анализа данных: фильтрации, группировки, сводные таблицы, time series.
# - Отработаете обработку данных (пропуски, дубликаты, типы, категориальные признаки).
# - Подготовитесь к следующему этапу — практическому машинному обучению.
#
# Развиваемые навыки: NumPy, Pandas, предобработка данных, статистика, работа с временем и файлами, аналитическое мышление — всё, что нужно ИИ-инженеру.
#
# Что дальше после завершения?
# - Переход к ML-этапу: моделирование (sklearn), кросс-валидация, пайплайны.
# - Инженерия фич и подготовка датасетов.
# - Построение API (FastAPI) и прототипов AI-продуктов.
#
# Готов? Вперёд — шаг за шагом, неделя за неделей. 🔥

# %% [markdown]
# # 🧭 НЕДЕЛЯ 1 — Основы NumPy и Pandas
# Цель недели: Понимание основных операций с массивами и таблицами.
#
# ## 🧰 Введение в методы недели
# Ниже — быстрый обзор приёмов, которые пригодятся в заданиях.
#
# ### 🧮 NumPy
# - `np.array()` — создание массива.
# - `np.zeros()`, `np.ones()` — массивы из нулей/единиц.
# - `np.arange()` — последовательности.
# - `np.random.randint()` — случайные целые.
# - `reshape()` — изменение формы массива.
# - `max()`, `min()`, `mean()` — базовая статистика.
# - `.T` — транспонирование.
# - Поэлементные операции: `+`, `-`, `*`, `/`.
# - Индексация, срезы, булева индексация.
# - `.to_numpy()` — из DataFrame в NumPy.
# - `np.linalg.det()` — определитель матрицы.
#
# ### 📊 Pandas
# - `pd.DataFrame()`, `pd.Series()` — базовые структуры.
# - `head()`, `info()`, `describe()` — обзор данных.
# - Индексация: `df["колонка"]`, булева фильтрация.
# - Добавление/удаление/переименование столбцов: присваивание, `drop()`, `rename()`.
# - `sum()`, `.str.upper()`, `fillna()`, `drop_duplicates()`.
# - `pd.get_dummies()` — one-hot.
# - `apply()`, `groupby()` — функции и группировки.
#
# 💡 Совет: Начинайте с простоты, затем усложняйте. Фиксируйте инсайты в комментариях кода.

# %% [markdown]
# ## 💡 EASY Задания (20)

# %% [markdown]
# 1) Создайте одномерный массив NumPy из 10 нулей, используя `np.zeros()`.
#
# _Подсказка: np.zeros(10)_

# %%
# 🧩 Ваш код здесь
import numpy as np~~~~~~~~

# %% [markdown]
# 2) Создайте одномерный массив NumPy из 10 единиц, используя `np.ones()`.

# %%
# 🧩 Ваш код здесь

# %% [markdown]
# 3) Создайте одномерный массив NumPy из 10 случайных целых чисел в диапазоне от 1 до 100, используя `np.random.randint()`.
#
# _Подсказка: np.random.randint(1, 101, size=10)_

# %%
# 🧩 Ваш код здесь

# %% [markdown]
# 4) Создайте массив NumPy 3x3 со значениями от 0 до 8, используя `np.arange()` и `reshape()`.

# %%
# 🧩 Ваш код здесь

# %% [markdown]
# 5) Измените форму массива из предыдущего задания на 1x9, используя `reshape()`.

# %%
# 🧩 Ваш код здесь

# %% [markdown]
# 6) Создайте массив NumPy 5x5 со случайными значениями и найдите максимальное, минимальное и среднее значение, используя `max()`, `min()`, `mean()`.
#
# _Подсказка: np.random.random((5,5))_

# %%
# 🧩 Ваш код здесь

# %% [markdown]
# 7) Создайте массив NumPy со значениями от 1 до 10 и извлеките все четные числа, используя булеву индексацию.

# %%
# 🧩 Ваш код здесь

# %% [markdown]
# 8) Создайте массив NumPy 2x3 и транспонируйте его, используя `.T`.

# %%
# 🧩 Ваш код здесь

# %% [markdown]
# 9) Создайте два массива NumPy одинаковой формы и выполните поэлементное сложение, вычитание, умножение и деление.

# %%
# 🧩 Ваш код здесь

# %% [markdown]
# 10) Создайте DataFrame Pandas из словаря с данными о студентах (имя, возраст, оценка), используя `pd.DataFrame()`.

# %%
# 🧩 Ваш код здесь
import pandas as pd

# %% [markdown]
# 11) Выведите первые 3 строки созданного DataFrame, используя `head()`.

# %%
# 🧩 Ваш код здесь

# %% [markdown]
# 12) Выведите информацию о DataFrame (типы данных, количество непустых значений), используя `info()`.

# %%
# 🧩 Ваш код здесь

# %% [markdown]
# 13) Выведите описательную статистику для числовых столбцов DataFrame, используя `describe()`.

# %%
# 🧩 Ваш код здесь

# %% [markdown]
# 14) Выберите столбец 'имя' из DataFrame, используя синтаксис `df['колонка']`.

# %%
# 🧩 Ваш код здесь

# %% [markdown]
# 15) Выберите строки DataFrame, где 'возраст' больше 20, используя булеву индексацию.

# %%
# 🧩 Ваш код здесь

# %% [markdown]
# 16) Добавьте новый столбец 'город' в DataFrame.

# %%
# 🧩 Ваш код здесь

# %% [markdown]
# 17) Удалите столбец 'город' из DataFrame, используя `drop()`.

# %%
# 🧩 Ваш код здесь

# %% [markdown]
# 18) Переименуйте столбец 'оценка' в 'балл' в DataFrame, используя `rename()`.
#
# _Подсказка: df.rename(columns={"оценка": "балл"}, inplace=True)_

# %%
# 🧩 Ваш код здесь

# %% [markdown]
# 19) Создайте Series Pandas из списка чисел и найдите его сумму, используя `sum()`.

# %%
# 🧩 Ваш код здесь

# %% [markdown]
# 20) Создайте Series Pandas из списка строк и преобразуйте его в верхний регистр, используя `.str.upper()`.

# %%
# 🧩 Ваш код здесь

# %% [markdown]
# 🔥 Отличная разминка! Дальше — посерьёзнее.

# %% [markdown]
# ## ⚙️ MEDIUM Задания (10)

# %% [markdown]
# 1) Создайте DataFrame из массива NumPy 4x4 случайных чисел. Затем сгруппируйте данные по первому столбцу (если он категориальный) и вычислите среднее значение второго столбца, а результат агрегации преобразуйте обратно в массив NumPy.
#
# _Подсказка: df.groupby(0)[1].mean().to_numpy()_

# %%
# 🧩 Ваш код здесь
import numpy as np, pandas as pd

# %% [markdown]
# 2) Создайте массив NumPy 4x4 со случайными числами. Замените все значения в центральном квадрате 2x2 на 0, используя срезы и присваивание.

# %%
# 🧩 Ваш код здесь

# %% [markdown]
# 3) Создайте массив NumPy 5x5. Нормализуйте все значения в массиве так, чтобы они находились в диапазоне от 0 до 1, используя формулу `(x - min) / (max - min)` и `min()`, `max()`.

# %%
# 🧩 Ваш код здесь

# %% [markdown]
# 4) Создайте два одномерных массива NumPy `a` и `b`. Объедините их в один двумерный массив, используя `np.vstack()` и `np.hstack()`.

# %%
# 🧩 Ваш код здесь

# %% [markdown]
# 5) Создайте DataFrame Pandas с данными о продажах (товар, количество, цена). Вычислите общую стоимость для каждой строки (количество * цена), используя поэлементное умножение столбцов.
#
# _Подсказка: df["итог"] = df["количество"] * df["цена"]_

# %%
# 🧩 Ваш код здесь
import pandas as pd

# %% [markdown]
# 6) Загрузите CSV-файл с данными о погоде (дата, температура, влажность). Отфильтруйте строки, где температура выше среднего значения по всему столбцу, используя `mean()`.

# %%
# 🧩 Ваш код здесь
# Пример: df = pd.read_csv("weather.csv")

# %% [markdown]
# 7) Создайте DataFrame с пропущенными значениями (NaN). Заполните все пропущенные значения в числовом столбце его средним значением, используя `fillna()` и `mean()`.

# %%
# 🧩 Ваш код здесь

# %% [markdown]
# 8) Создайте DataFrame с дублирующимися строками. Удалите дубликаты, сохраняя только первое вхождение, используя `drop_duplicates()`.

# %%
# 🧩 Ваш код здесь

# %% [markdown]
# 9) Создайте DataFrame с категориальным столбцом. Преобразуйте его в числовой формат с помощью One-Hot Encoding, используя `pd.get_dummies()`.

# %%
# 🧩 Ваш код здесь

# %% [markdown]
# 10) Создайте DataFrame с числовым столбцом. Примените функцию, которая возводит каждое число в квадрат, используя `apply()` и лямбда-функцию.

# %%
# 🧩 Ваш код здесь

# %% [markdown]
# 💪 Хороший темп! Ещё немного — и вы почувствуете силу векторизации.

# %% [markdown]
# ## 🔥 HARD Задания (5)

# %% [markdown]
# 1) Используя NumPy, реализуйте функцию для вычисления ковариационной матрицы двух массивов без использования `np.cov()`. Сравните результат с `np.cov()`.
#
# _Подсказка: центрируйте данные и используйте матричное умножение_

# %%
# 🧩 Ваш код здесь
import numpy as np

# %% [markdown]
# 2) Создайте DataFrame Pandas с данными о транзакциях (ID пользователя, сумма, дата). Найдите топ-5 пользователей по общей сумме транзакций за последний месяц, используя фильтрацию по дате, `groupby()`, `sum()`, `nlargest()`.

# %%
# 🧩 Ваш код здесь
import pandas as pd
from datetime import datetime, timedelta

# %% [markdown]
# 3) Используя NumPy, реализуйте алгоритм K-Means для кластеризации случайных 2D точек без использования библиотек машинного обучения (только базовые операции NumPy).

# %%
# 🧩 Ваш код здесь
# Шаги: инициализация центров, назначение кластеров, пересчёт центров, цикл до сходимости

# %% [markdown]
# 4) Загрузите большой CSV-файл (например, 100 000 строк). Эффективно вычислите скользящее среднее для числового столбца с окном в 10 элементов, используя `rolling().mean()`.

# %%
# 🧩 Ваш код здесь
# Пример: df['roll_mean'] = df['col'].rolling(10).mean()

# %% [markdown]
# 5) Создайте DataFrame с иерархическим индексом (MultiIndex) для данных о продажах по регионам и продуктам. Выберите данные для конкретного региона и всех продуктов, используя `loc[]`.

# %%
# 🧩 Ваш код здесь
# Подсказка: df.loc[("Регион_A", slice(None)), :]

# %% [markdown]
# 🏆 Это был серьёзный вызов — отличная работа!

# %% [markdown]
# ## 🧠 CONCEPT Задания (5)

# %% [markdown]
# 1) Объясните разницу между `ndarray` и `DataFrame` в контексте хранения и обработки данных. Когда следует использовать каждый из них?

# %% [markdown]
# ✍️ Ваш ответ здесь

# %% [markdown]
# 2) Опишите концепцию векторизации в NumPy. Почему она важна для производительности и как она работает?

# %% [markdown]
# ✍️ Ваш ответ здесь
#
# _Подсказка: операции над массивами без явных Python-циклов_

# %% [markdown]
# 3) Объясните, что такое широковещание (broadcasting) в NumPy. Приведите примеры его использования и правила.

# %% [markdown]
# ✍️ Ваш ответ здесь

# %% [markdown]
# 4) В чем разница между копией и представлением (view) массива в NumPy? Приведите примеры, когда создается копия, а когда представление.

# %% [markdown]
# ✍️ Ваш ответ здесь

# %% [markdown]
# 5) Опишите основные типы данных (dtypes) в NumPy и Pandas. Почему важно правильно выбирать тип данных для столбца или массива?

# %% [markdown]
# ✍️ Ваш ответ здесь

# %% [markdown]
# 🎯 Неделя 1 завершена! Хорошая основа заложена.
#
# 🏁 Поздравляем! Неделя 1 завершена.
#
# 💪 Вы продвинулись на 20% пути к профессиональному уровню.

# %% [markdown]
# # 🧭 НЕДЕЛЯ 2 — Индексация, агрегация, объединение
#
# ## 🧰 Введение в методы недели
# ### 🧮 NumPy
# - Индексация (прямая, срезы), `reshape()`, `flatten()`, `sum(axis)`, `astype()`, `np.sqrt()`, `max(axis)`, `np.where()`, `np.unique()`, `argsort()`
#
# ### 📊 Pandas
# - `loc[]`, `iloc[]`, `sum()`, `value_counts()`, `pd.merge()`, `.dt.year`, арифметика столбцов, `sort_values()`, `reset_index()`, `groupby()`, `fillna()`, `pd.concat()`, `pd.qcut()`, `pct_change()`, `rolling().mean()`, `agg()`, `pivot_table()`, `filter()`, `size()`
#
# 💡 Совет: внимательно различайте индексацию по метке и по позиции.

# %% [markdown]
# ## 💡 EASY Задания (20)

# %% [markdown]
# 1) Создайте массив NumPy 4x4 со случайными целыми числами от 1 до 10. Извлеките элемент во второй строке, третьем столбце, используя прямую индексацию.

# %%
# 🧩 Ваш код здесь
import numpy as np

# %% [markdown]
# 2) Создайте DataFrame Pandas из 5 строк и 3 столбцов с произвольными данными. Выберите столбец по его имени.

# %%
# 🧩 Ваш код здесь
import pandas as pd

# %% [markdown]
# 3) Создайте массив NumPy 3x3. Извлеките первую строку и последний столбец, используя срезы.
#
# _Подсказка: a[0, :], a[:, -1]_

# %%
# 🧩 Ваш код здесь

# %% [markdown]
# 4) Создайте DataFrame Pandas. Выберите строки с индексами 0, 2, 4, используя `loc[]`.

# %%
# 🧩 Ваш код здесь
# Подсказка: df.loc[[0,2,4]]

# %% [markdown]
# 5) Создайте массив NumPy 5x5. Извлеките подмассив, состоящий из центральных 3x3 элементов.

# %%
# 🧩 Ваш код здесь
# Подсказка: a[1:4,1:4]

# %% [markdown]
# 6) Создайте DataFrame Pandas. Выберите строки с индексами 1, 3 и столбцы с индексами 0, 2, используя `iloc[]`.

# %%
# 🧩 Ваш код здесь
# Пример: df.iloc[[1,3],[0,2]]

# %% [markdown]
# 7) Создайте массив NumPy 1D из 10 элементов. Измените его форму на 2D (2x5), затем обратно на 1D, используя `reshape()` и `flatten()`.

# %%
# 🧩 Ваш код здесь

# %% [markdown]
# 8) Создайте DataFrame Pandas с числовым столбцом. Найдите сумму всех значений в этом столбце, используя `sum()`.

# %%
# 🧩 Ваш код здесь

# %% [markdown]
# 9) Создайте массив NumPy 3x3. Найдите сумму элементов по каждой строке и по каждому столбцу, используя `sum()` с параметром `axis`.

# %%
# 🧩 Ваш код здесь

# %% [markdown]
# 10) Создайте DataFrame Pandas с категориальным столбцом. Подсчитайте количество уникальных значений в этом столбце, используя `value_counts()`.

# %%
# 🧩 Ваш код здесь

# %% [markdown]
# 11) Создайте два DataFrame Pandas с общим столбцом. Объедините их по этому столбцу, используя `pd.merge()` с типом `inner`.

# %%
# 🧩 Ваш код здесь

# %% [markdown]
# 12) Создайте массив NumPy 1D. Измените его тип данных на `float64`, используя `astype()`.

# %%
# 🧩 Ваш код здесь

# %% [markdown]
# 13) Создайте DataFrame Pandas с датами. Извлеките год из столбца дат, используя аксессор `.dt.year`.

# %%
# 🧩 Ваш код здесь
# Пример: pd.to_datetime(df['дата']).dt.year

# %% [markdown]
# 14) Создайте массив NumPy. Примените к нему универсальную функцию `np.sqrt()`.
#
# _Важно: следите за отрицательными значениями_

# %%
# 🧩 Ваш код здесь

# %% [markdown]
# 15) Создайте DataFrame Pandas. Добавьте новый столбец, который является результатом деления двух существующих числовых столбцов.

# %%
# 🧩 Ваш код здесь

# %% [markdown]
# 16) Создайте массив NumPy 2D. Найдите максимальное значение в каждой строке, используя `max()` с параметром `axis`.

# %%
# 🧩 Ваш код здесь

# %% [markdown]
# 17) Создайте DataFrame Pandas. Отсортируйте его по значениям одного из столбцов в порядке убывания, используя `sort_values()`.

# %%
# 🧩 Ваш код здесь

# %% [markdown]
# 18) Создайте массив NumPy 1D. Используйте `np.where()` для замены всех значений больше 5 на 10.

# %%
# 🧩 Ваш код здесь

# %% [markdown]
# 19) Создайте DataFrame Pandas. Сбросьте его индекс и сделайте старый индекс новым столбцом, используя `reset_index()`.

# %%
# 🧩 Ваш код здесь

# %% [markdown]
# 20) Создайте массив NumPy из случайных чисел. Найдите все уникальные значения в массиве, используя `np.unique()`.

# %%
# 🧩 Ваш код здесь

# %% [markdown]
# 🔥 Отличная работа, двигаемся дальше!

# %% [markdown]
# ## ⚙️ MEDIUM Задания (10)

# %% [markdown]
# 1) Загрузите CSV-файл с данными о продажах (дата, регион, товар, сумма). Сгруппируйте данные по 'региону' и 'товару' и вычислите общую сумму продаж для каждой группы, используя `groupby()` и `sum()`.

# %%
# 🧩 Ваш код здесь
# Пример: df.groupby(['регион','товар'])['сумма'].sum()

# %% [markdown]
# 2) Создайте массив NumPy 2D. Отфильтруйте строки, где сумма элементов строки превышает заданный порог, используя `np.sum()` и булеву индексацию.

# %%
# 🧩 Ваш код здесь

# %% [markdown]
# 3) Создайте два DataFrame Pandas: один с информацией о сотрудниках (ID, Имя, Отдел), другой с информацией о зарплатах (ID, Зарплата, Дата). Объедините их, чтобы получить полную информацию о зарплатах сотрудников, используя `pd.merge()` с типом `left`.

# %%
# 🧩 Ваш код здесь
import pandas as pd

# %% [markdown]
# 4) Создайте DataFrame Pandas с пропущенными значениями. Заполните пропущенные значения в каждом столбце методом `ffill()` (forward fill).

# %%
# 🧩 Ваш код здесь

# %% [markdown]
# 5) Используя NumPy, создайте матрицу 5x5. Вычислите среднее значение каждого столбца, исключая максимальное и минимальное значения в этом столбце.
#
# _Подсказка: используйте сортировку или маски_

# %%
# 🧩 Ваш код здесь
import numpy as np

# %% [markdown]
# 6) Создайте DataFrame Pandas с данными о заказах (ID заказа, ID клиента, Сумма). Найдите ID клиентов, которые сделали более 3 заказов, и общую сумму их заказов, используя `groupby()`, `size()`, `filter()`.

# %%
# 🧩 Ваш код здесь
import pandas as pd

# %% [markdown]
# 7) Создайте массив NumPy 2D. Отсортируйте его по значениям второго столбца, используя `argsort()`.

# %%
# 🧩 Ваш код здесь
import numpy as np

# %% [markdown]
# 8) Создайте DataFrame Pandas с числовым столбцом. Разбейте этот столбец на 4 равных интервала (квантили) и присвойте каждой строке метку интервала, используя `pd.qcut()`.

# %%
# 🧩 Ваш код здесь
import pandas as pd

# %% [markdown]
# 9) Создайте два DataFrame Pandas. Объедините их вертикально, добавив один под другой, используя `pd.concat()`.

# %%
# 🧩 Ваш код здесь
import pandas as pd

# %% [markdown]
# 10) Используя NumPy, реализуйте функцию для вычисления евклидова расстояния между двумя векторами.

# %%
# 🧩 Ваш код здесь
import numpy as np

# %% [markdown]
# 🔥 Отлично! Вы уверенно управляете индексами и группировками.

# %% [markdown]
# ## 🔥 HARD Задания (5)

# %% [markdown]
# 1) Загрузите данные о ценах акций (дата, цена открытия, цена закрытия). Вычислите ежедневную доходность акций, а затем скользящую среднюю доходность за 7 дней, используя `pct_change()` и `rolling().mean()`.

# %%
# 🧩 Ваш код здесь
import pandas as pd

# %% [markdown]
# 2) Используя NumPy, создайте функцию, которая принимает 2D массив и возвращает массив, где каждая строка нормализована по L2-норме (евклидова норма).

# %%
# 🧩 Ваш код здесь
import numpy as np

# %% [markdown]
# 3) Создайте DataFrame Pandas с данными о транзакциях (ID клиента, дата, сумма). Найдите для каждого клиента его первую и последнюю транзакцию, а также среднюю сумму транзакции, используя `groupby()` и агрегацию с `agg()`.

# %%
# 🧩 Ваш код здесь
import pandas as pd

# %% [markdown]
# 4) Используя NumPy, реализуйте функцию для нахождения k-ближайших соседей для заданной точки в 2D пространстве (без использования готовых библиотек ML).

# %%
# 🧩 Ваш код здесь
import numpy as np

# %% [markdown]
# 5) Создайте DataFrame Pandas с несколькими категориальными столбцами. Создайте сводную таблицу (pivot table), которая показывает среднее значение числового столбца для каждой комбинации категорий, используя `pivot_table()`.

# %%
# 🧩 Ваш код здесь
import pandas as pd

# %% [markdown]
# 🏆 Отличная выносливость!

# %% [markdown]
# ## 🧠 CONCEPT Задания (5)

# %% [markdown]
# 1) Объясните разницу между `loc[]` и `iloc[]` в Pandas. Приведите примеры, когда каждый из них предпочтителен.

# %% [markdown]
# ✍️ Ваш ответ здесь

# %% [markdown]
# 2) Что такое агрегация данных в Pandas? Приведите примеры часто используемых агрегирующих функций и их применение.

# %% [markdown]
# ✍️ Ваш ответ здесь

# %% [markdown]
# 3) Опишите концепцию объединения (merge, join, concatenate) в Pandas. В чем их различия и когда какой метод использовать?

# %% [markdown]
# ✍️ Ваш ответ здесь
#
# _Подсказка: join по индексам, merge по столбцам, concat по осям_

# %% [markdown]
# 4) Объясните, что такое MultiIndex (иерархический индекс) в Pandas. Приведите примеры его создания и использования для индексации данных.

# %% [markdown]
# ✍️ Ваш ответ здесь

# %% [markdown]
# 5) В чем преимущества и недостатки использования `apply()` по сравнению с векторизованными операциями в Pandas?

# %% [markdown]
# ✍️ Ваш ответ здесь

# %% [markdown]
# 🏁 Поздравляем! Неделя 2 завершена.
#
# 💪 Вы продвинулись на 40% пути к профессиональному уровню.

# %% [markdown]
# # 🧭 НЕДЕЛЯ 3 — Обработка данных, очистка, статистика
#
# ## 🧰 Введение в методы недели
# ### 🧮 NumPy
# - `np.nan`, булевы маски, `np.mean/median/std/sum`, `np.power`, `np.clip`
#
# ### 📊 Pandas
# - `isnull()`, `fillna()`, `drop_duplicates()`, `astype()`, `mean/median/std/mode`, `cumsum()`, `pd.to_datetime()`, `.dt.*`, `.str.*`, `nunique()`, `round()`, `pct_change()`, `pd.cut()`, `corr()`, `groupby()`, `agg()`, `idxmax()`
#
# 💡 Совет: фиксируйте выбранную стратегию обработки пропусков.

# %% [markdown]
# ## 💡 EASY Задания (20)

# %% [markdown]
# 1) Создайте DataFrame Pandas с 5 строками и 3 столбцами, содержащий несколько пропущенных значений (NaN). Проверьте наличие пропущенных значений, используя `isnull()` и `sum()`.

# %%
# 🧩 Ваш код здесь
import pandas as pd
import numpy as np

# %% [markdown]
# 2) Создайте массив NumPy 1D с 10 элементами, включая несколько `np.nan`. Удалите все `np.nan` из массива, используя булеву индексацию.
#
# _Подсказка: ~np.isnan(a)_

# %%
# 🧩 Ваш код здесь
import numpy as np

# %% [markdown]
# 3) Создайте DataFrame Pandas. Заполните все пропущенные значения в числовом столбце нулем, используя `fillna(0)`.

# %%
# 🧩 Ваш код здесь
import pandas as pd

# %% [markdown]
# 4) Создайте DataFrame с двумя одинаковыми строками. Удалите дубликаты, используя `drop_duplicates()`.

# %%
# 🧩 Ваш код здесь
import pandas as pd

# %% [markdown]
# 5) Создайте Series Pandas с числовыми данными, представленными как строки (например, '10', '20', '30'). Преобразуйте его в числовой тип данных, используя `astype(int)`.

# %%
# 🧩 Ваш код здесь
import pandas as pd

# %% [markdown]
# 6) Создайте массив NumPy 1D из 10 случайных чисел. Найдите его среднее значение, медиану и стандартное отклонение, используя `np.mean()`, `np.median()`, `np.std()`.

# %%
# 🧩 Ваш код здесь
import numpy as np

# %% [markdown]
# 7) Создайте DataFrame Pandas с данными о возрасте. Найдите средний возраст, используя `mean()`.

# %%
# 🧩 Ваш код здесь
import pandas as pd

# %% [markdown]
# 8) Создайте DataFrame с категориальным столбцом. Найдите моду (наиболее часто встречающееся значение) в этом столбце, используя `mode()`.

# %%
# 🧩 Ваш код здесь
import pandas as pd

# %% [markdown]
# 9) Создайте DataFrame с числовым столбцом. Вычислите кумулятивную сумму этого столбца, используя `cumsum()`.

# %%
# 🧩 Ваш код здесь
import pandas as pd

# %% [markdown]
# 10) Создайте массив NumPy 2D. Вычислите сумму элементов по каждой строке, используя `np.sum(axis=1)`.

# %%
# 🧩 Ваш код здесь
import numpy as np

# %% [markdown]
# 11) Создайте DataFrame Pandas с датами. Отфильтруйте строки, где дата находится до определенного года, используя `pd.to_datetime()` и булеву индексацию.

# %%
# 🧩 Ваш код здесь
import pandas as pd

# %% [markdown]
# 12) Создайте Series Pandas с текстовыми данными. Преобразуйте все строки в нижний регистр, используя `.str.lower()`.

# %%
# 🧩 Ваш код здесь
import pandas as pd

# %% [markdown]
# 13) Создайте массив NumPy 1D. Примените к каждому элементу функцию, которая возводит его в куб, используя `np.power()` или `**`.

# %%
# 🧩 Ваш код здесь
import numpy as np

# %% [markdown]
# 14) Создайте DataFrame Pandas. Вычислите количество уникальных значений в каждом столбце, используя `nunique()`.

# %%
# 🧩 Ваш код здесь
import pandas as pd

# %% [markdown]
# 15) Создайте DataFrame с числовым столбцом. Округлите все значения до двух десятичных знаков, используя `round()`.

# %%
# 🧩 Ваш код здесь
import pandas as pd
import numpy as np

# %% [markdown]
# 16) Создайте массив NumPy 2D. Замените все значения, превышающие 10, на 10, используя `np.clip()`.

# %%
# 🧩 Ваш код здесь
import numpy as np

# %% [markdown]
# 17) Создайте DataFrame Pandas. Добавьте новый столбец, который является индикатором (True/False) для строк, где значение в другом столбце больше заданного порога.

# %%
# 🧩 Ваш код здесь
import pandas as pd

# %% [markdown]
# 18) Создайте Series Pandas. Проверьте, содержит ли каждая строка определенную подстроку, используя `.str.contains()`.

# %%
# 🧩 Ваш код здесь
import pandas as pd

# %% [markdown]
# 19) Создайте массив NumPy 1D. Отсортируйте его в порядке убывания, используя `np.sort()` и срезы.

# %%
# 🧩 Ваш код здесь
import numpy as np

# %% [markdown]
# 20) Создайте DataFrame Pandas. Вычислите процент пропущенных значений для каждого столбца.
#
# _Подсказка: df.isnull().mean()*100_

# %%
# 🧩 Ваш код здесь
import pandas as pd

# %% [markdown]
# 🔥 Мощная чистка данных — фундамент точных выводов!

# %% [markdown]
# ## ⚙️ MEDIUM Задания (10)

# %% [markdown]
# 1) Загрузите CSV-файл с данными о продажах, содержащий пропущенные значения. Заполните пропущенные значения в столбце 'Цена' медианой этого столбца, а в столбце 'Категория' — наиболее частым значением (модой), используя `fillna()` и `median()`, `mode()`.

# %%
# 🧩 Ваш код здесь
# Подсказка: df['Цена'] = df['Цена'].fillna(df['Цена'].median())
# df['Категория'] = df['Категория'].fillna(df['Категория'].mode()[0])

# %% [markdown]
# 2) Создайте массив NumPy 2D. Выполните стандартизацию данных (Z-score нормализацию) для каждого столбца: `(x - mean) / std`, используя `np.mean()` и `np.std()` с параметром `axis`.

# %%
# 🧩 Ваш код здесь
import numpy as np

# %% [markdown]
# 3) Создайте DataFrame Pandas с данными о времени (например, время начала и окончания события). Вычислите продолжительность каждого события в минутах, используя разность дат и `dt.total_seconds()`.

# %%
# 🧩 Ваш код здесь
import pandas as pd
from datetime import timedelta

# %% [markdown]
# 4) Загрузите CSV-файл с данными о погоде (температура, осадки). Создайте новый столбец 'Температурная_категория' на основе значений температуры (например, 'Холодно', 'Нормально', 'Жарко'), используя `pd.cut()`.

# %%
# 🧩 Ваш код здесь
import pandas as pd
import numpy as np

# %% [markdown]
# 5) Создайте DataFrame с данными о ценах акций. Вычислите ежедневное изменение цен в процентах и добавьте его как новый столбец, используя `pct_change()`.

# %%
# 🧩 Ваш код здесь
import pandas as pd

# %% [markdown]
# 6) Используя NumPy, реализуйте функцию для удаления выбросов (outliers) из одномерного массива, используя метод IQR (интерквартильный размах).

# %%
# 🧩 Ваш код здесь
import numpy as np

# %% [markdown]
# 7) Создайте DataFrame Pandas с текстовым столбцом. Извлеките числовые значения из строк (например, 'Цена: 123.45 USD') и преобразуйте их в числовой тип, используя `.str.extract()` и `astype()`.

# %%
# 🧩 Ваш код здесь
import pandas as pd

# %% [markdown]
# 8) Создайте DataFrame с несколькими числовыми столбцами. Вычислите корреляционную матрицу между всеми числовыми столбцами, используя `corr()`.

# %%
# 🧩 Ваш код здесь
import pandas as pd

# %% [markdown]
# 9) Создайте DataFrame с данными о транзакциях. Разделите столбец 'Дата' на отдельные столбцы 'Год', 'Месяц', 'День', используя `dt.year`, `dt.month`, `dt.day`.

# %%
# 🧩 Ваш код здесь
import pandas as pd

# %% [markdown]
# 10) Создайте DataFrame с данными о транзакциях. Реализуйте функцию для экспоненциального скользящего среднего (EMA) без спец. библиотек и примените её к столбцу суммы.

# %%
# 🧩 Ваш код здесь
import numpy as np

# %% [markdown]
# 🏆 Великолепно! Вы приручили пропуски и статистику.

# %% [markdown]
# ## 🔥 HARD Задания (5)

# %% [markdown]
# 1) Загрузите большой CSV-файл с данными о сенсорах (timestamp, sensor_id, value). Определите, какие сенсоры имеют аномально большое количество пропущенных значений (например, более 20%), используя `groupby()`, `isnull().sum()`, и фильтрацию.

# %%
# 🧩 Ваш код здесь
import pandas as pd

# %% [markdown]
# 2) Используя NumPy, реализуйте функцию для сглаживания временного ряда с помощью экспоненциального скользящего среднего (Exponential Moving Average) без использования специализированных библиотек.

# %%
# 🧩 Ваш код здесь
import numpy as np

# %% [markdown]
# 3) Создайте DataFrame Pandas с данными о клиентах (ID, Дата_регистрации, Дата_последней_активности). Вычислите 'возраст' клиента в днях и 'давность' последней активности в днях, используя `pd.to_datetime()` и разность дат.

# %%
# 🧩 Ваш код здесь
import pandas as pd
from datetime import datetime

# %% [markdown]
# 4) Используя NumPy, создайте функцию для выполнения взвешенной линейной регрессии (Weighted Least Squares) для заданных данных `x`, `y` и весов `w`.

# %%
# 🧩 Ваш код здесь
import numpy as np

# %% [markdown]
# 5) Создайте DataFrame с данными о продажах (Регион, Товар, Дата, Сумма). Для каждого региона и каждого товара найдите месяц с максимальной суммой продаж, используя `groupby()`, `dt.month`, `idxmax()`.

# %%
# 🧩 Ваш код здесь
import pandas as pd

# %% [markdown]
# 🔥 Сильный прогресс! Ваша статистика — на уровне практика.
#
# 🏁 Поздравляем! Неделя 3 завершена.
#
# 💪 Вы продвинулись на 60% пути к профессиональному уровню.

# %% [markdown]
# # 🧭 НЕДЕЛЯ 4 — Мини-проекты и реальные датасеты
#
# ## 🧰 Введение в методы недели
# ### 🧮 NumPy
# - `np.save()`, `np.load()`, `np.percentile()`, `np.eye()`, `np.random.normal()`, `np.linalg.svd()`
#
# ### 📊 Pandas
# - `pd.read_csv()`, `to_csv()`, `head()`, `info()`, `.columns`, `value_counts()`, `nunique()`, `replace()`, `groupby()`, `mean()`, `sum()`, `filter()`, `agg()`, `pd.to_datetime()`, `.dt.month`, `fillna()`, `map()`, `merge()`, `.str.extract()`, `interpolate()`, `quantile()`, `std()`
#
# 💡 Совет: держите данные в порядке — чистота колонок экономит часы.

# %% [markdown]
# ## 💡 EASY Задания (20)

# %% [markdown]
# 1) Загрузите небольшой CSV-файл (например, с данными о продажах) в DataFrame Pandas, используя `pd.read_csv()`.

# %%
# 🧩 Ваш код здесь
import pandas as pd
# df = pd.read_csv('file.csv')

# %% [markdown]
# 2) Просмотрите первые 5 строк загруженного DataFrame, используя `head()`.

# %%
# 🧩 Ваш код здесь

# %% [markdown]
# 3) Выведите названия всех столбцов DataFrame, используя `.columns`.

# %%
# 🧩 Ваш код здесь

# %% [markdown]
# 4) Проверьте типы данных каждого столбца в DataFrame, используя `info()`.

# %%
# 🧩 Ваш код здесь

# %% [markdown]
# 5) Подсчитайте количество уникальных значений в одном из категориальных столбцов DataFrame, используя `value_counts()`.

# %%
# 🧩 Ваш код здесь

# %% [markdown]
# 6) Создайте новый столбец в DataFrame, который является результатом простой арифметической операции между двумя существующими числовыми столбцами.

# %%
# 🧩 Ваш код здесь

# %% [markdown]
# 7) Отфильтруйте DataFrame, чтобы отобразить только строки, где значение в определенном столбце превышает заданный порог.

# %%
# 🧩 Ваш код здесь

# %% [markdown]
# 8) Сгруппируйте DataFrame по одному категориальному столбцу и вычислите среднее значение другого числового столбца для каждой группы, используя `groupby()` и `mean()`.

# %%
# 🧩 Ваш код здесь
import pandas as pd

# %% [markdown]
# 9) Создайте массив NumPy 3x3 со случайными числами. Сохраните его в файл в формате `.npy`, используя `np.save()`.

# %%
# 🧩 Ваш код здесь
import numpy as np

# %% [markdown]
# 10) Загрузите массив из файла `.npy`, используя `np.load()`.

# %%
# 🧩 Ваш код здесь
import numpy as np

# %% [markdown]
# 11) Создайте DataFrame Pandas и сохраните его в CSV-файл без индекса, используя `to_csv(index=False)`.

# %%
# 🧩 Ваш код здесь
import pandas as pd

# %% [markdown]
# 12) Загрузите DataFrame из CSV-файла, который вы только что сохранили.

# %%
# 🧩 Ваш код здесь
import pandas as pd

# %% [markdown]
# 13) Используя NumPy, создайте массив из 100 случайных чисел, представляющих собой имитацию результатов эксперимента. Найдите 95-й перцентиль, используя `np.percentile()`.

# %%
# 🧩 Ваш код здесь
import numpy as np

# %% [markdown]
# 14) В DataFrame с данными о продажах, найдите общую сумму продаж для каждого продукта, используя `groupby()` и `sum()`.

# %%
# 🧩 Ваш код здесь
import pandas as pd

# %% [markdown]
# 15) Создайте DataFrame с датами. Отфильтруйте данные за определенный месяц.

# %%
# 🧩 Ваш код здесь
import pandas as pd
from datetime import datetime

# %% [markdown]
# 16) Используя NumPy, создайте матрицу идентичности 4x4, используя `np.eye()`.

# %%
# 🧩 Ваш код здесь
import numpy as np

# %% [markdown]
# 17) В DataFrame, замените все вхождения определенного значения в столбце на другое значение, используя `replace()`.

# %%
# 🧩 Ваш код здесь
import pandas as pd

# %% [markdown]
# 18) Создайте DataFrame из нескольких Series.

# %%
# 🧩 Ваш код здесь
import pandas as pd
import numpy as np

# %% [markdown]
# 19) Используя NumPy, создайте массив из 1000 случайных чисел, распределенных по нормальному закону, используя `np.random.normal()`.

# %%
# 🧩 Ваш код здесь
import numpy as np

# %% [markdown]
# 20) В DataFrame, вычислите количество уникальных значений в каждом столбце, используя `nunique()`.

# %%
# 🧩 Ваш код здесь
import pandas as pd

# %% [markdown]
# 🔥 Отлично! Вы уверенно работаете с файлами и базовой аналитикой.

# %% [markdown]
# ## ⚙️ MEDIUM Задания (10)

# %% [markdown]
# 1) Загрузите датасет с информацией о пассажирах Титаника (например, `titanic.csv`). Очистите столбец 'Возраст', заполнив пропущенные значения медианой, и преобразуйте столбец 'Пол' в числовой формат (0/1), используя `fillna()` и `map()`.

# %%
# 🧩 Ваш код здесь
# df = pd.read_csv('titanic.csv')

# %% [markdown]
# 2) Используя NumPy, реализуйте функцию для вычисления матрицы расстояний между всеми парами точек в заданном наборе 2D точек.

# %%
# 🧩 Ваш код здесь
import numpy as np

# %% [markdown]
# 3) Загрузите датасет о ценах на недвижимость. Создайте новый признак 'Цена_за_кв_метр', а затем найдите среднюю цену за квадратный метр для каждого города, используя `groupby()`.

# %%
# 🧩 Ваш код здесь
import pandas as pd
import numpy as np

# %% [markdown]
# 4) Создайте два DataFrame: один с данными о пользователях (ID, Имя, Страна), другой с данными о покупках (ID_пользователя, Продукт, Сумма). Объедините их, чтобы получить список продуктов, купленных пользователями из определенной страны, используя `merge()` и фильтрацию.

# %%
# 🧩 Ваш код здесь
import pandas as pd

# %% [markdown]
# 5) Используя NumPy, создайте функцию для выполнения операции свертки (convolution) одномерного массива с заданным ядром (ядром фильтра).

# %%
# 🧩 Ваш код здесь
import numpy as np

# %% [markdown]
# 6) Загрузите датасет с временными рядами (например, ежедневные продажи). Вычислите ежемесячные агрегированные продажи и визуализируйте их (без использования библиотек для визуализации, только подготовка данных).

# %%
# 🧩 Ваш код здесь
import pandas as pd
from pandas.tseries.frequencies import to_offset

# %% [markdown]
# 7) Создайте DataFrame с текстовым столбцом, содержащим смешанные данные. Используйте регулярные выражения в Pandas (`.str.extract()`) для извлечения определенных числовых или текстовых паттернов.

# %%
# 🧩 Ваш код здесь
import pandas as pd
import re

# %% [markdown]
# 8) Используя NumPy, напишите функцию, которая принимает 2D массив и возвращает его главные компоненты (Principal Components) без использования `sklearn.decomposition.PCA`.

# %%
# 🧩 Ваш код здесь
import numpy as np

# %% [markdown]
# 9) Загрузите датасет с оценками студентов (Имя, Предмет, Оценка). Найдите студентов, у которых средний балл по всем предметам выше 4.5, используя `groupby()`, `mean()`, `filter()`.

# %%
# 🧩 Ваш код здесь
import pandas as pd

# %% [markdown]
# 10) Создайте DataFrame с иерархическим индексом (MultiIndex) из двух столбцов. Выполните агрегацию по одному из уровней индекса, используя `level` в `groupby()`.

# %%
# 🧩 Ваш код здесь
import pandas as pd

# %% [markdown]
# 🔥 Средний уровень освоен — вы готовы к тяжёлым задачам!

# %% [markdown]
# ## 🔥 HARD Задания (5)

# %% [markdown]
# 1) Загрузите большой датасет с логами веб-сервера (timestamp, IP, URL, status_code). Определите топ-10 самых посещаемых URL-адресов, количество уникальных посетителей для каждого URL и среднее время ответа (если доступно), используя `pd.to_datetime()`, `groupby()`, `nunique()`, `mean()`.

# %%
# 🧩 Ваш код здесь
import pandas as pd

# %% [markdown]
# 2) Используя NumPy, реализуйте алгоритм сингулярного разложения (SVD) для заданной матрицы. Сравните результат с `np.linalg.svd()`.

# %%
# 🧩 Ваш код здесь
import numpy as np
from numpy.linalg import svd

# %% [markdown]
# 3) Загрузите датасет с данными о транзакциях. Разработайте стратегию обнаружения аномалий, основанную на IQR или Z-score, для выявления необычно больших или малых транзакций, используя `quantile()`, `std()`, `mean()`.

# %%
# 🧩 Ваш код здесь
import pandas as pd
import numpy as np

# %% [markdown]
# 4) Создайте DataFrame с данными о временных рядах (например, ежедневные показания датчиков). Реализуйте функцию для обнаружения пропусков в данных и их интерполяции с использованием различных методов (линейная, полиномиальная) с помощью `interpolate()`.

# %%
# 🧩 Ваш код здесь
import pandas as pd
import numpy as np

# %% [markdown]
# 5) Используя NumPy, напишите функцию, которая принимает изображение (представленное как 3D массив RGB) и применяет к нему фильтр Гаусса (Gaussian blur) без использования `scipy.ndimage`.

# %%
# 🧩 Ваш код здесь
import numpy as np

# %% [markdown]
# 🏁 Поздравляем! Неделя 4 завершена.
#
# 💪 Вы продвинулись на 80% пути к профессиональному уровню.

# %% [markdown]
# # 🧭 НЕДЕЛЯ 5 — Продвинутые методы

# %% [markdown]
# ## 💡 EASY Задания (20)

# %% [markdown]
# 1) Используя `np.random.default_rng`, создайте генератор случайных чисел и сгенерируйте массив целых чисел размером 3x4 в диапазоне от 0 до 100.

# %%
# 🧩 Ваш код здесь
import numpy as np
rng = np.random.default_rng()

# %% [markdown]
# 2) Создайте одномерный массив `np.array` и примените `np.diff` для вычисления разностей между соседними элементами.

# %%
# 🧩 Ваш код здесь
import numpy as np

# %% [markdown]
# 3) Создайте массив случайных чисел и используйте `np.histogram` для построения гистограммы с 10 корзинами, вернув только значения гистограммы и границы корзин.

# %%
# 🧩 Ваш код здесь
import numpy as np

# %% [markdown]
# 4) Создайте функцию, которая возводит число в квадрат, затем используйте `np.vectorize` для создания векторизированной версии этой функции и примените ее к массиву чисел.

# %%
# 🧩 Ваш код здесь
import numpy as np

# %% [markdown]
# 5) Сгенерируйте два одномерных массива с помощью `np.random.default_rng` и вычислите их ковариацию с использованием `np.cov`.

# %%
# 🧩 Ваш код здесь
import numpy as np

# %% [markdown]
# 6) Создайте матрицу 3x3 и вычислите ее определитель с помощью `np.linalg.det`.

# %%
# 🧩 Ваш код здесь
from numpy.linalg import det

# %% [markdown]
# 7) Используйте `np.apply_along_axis` для вычисления среднего значения по каждой строке двумерного массива.

# %%
# 🧩 Ваш код здесь
import numpy as np

# %% [markdown]
# 8) Создайте одномерный массив и вычислите его градиент с помощью `np.gradient`.

# %%
# 🧩 Ваш код здесь
from numpy import gradient

# %% [markdown]
# 9) Сгенерируйте два массива случайных данных и вычислите их коэффициент корреляции с помощью `np.corrcoef`.

# %%
# 🧩 Ваш код здесь
import numpy as np

# %% [markdown]
# 10) Используя `pd.read_excel`, загрузите данные из фиктивного Excel-файла (например, `sales.xlsx`) в DataFrame. (Предположите, что файл существует).

# %%
# 🧩 Ваш код здесь
import pandas as pd
# df = pd.read_excel('sales.xlsx')

# %% [markdown]
# 11) Создайте DataFrame и используйте `pd.melt` для преобразования его из широкого формата в длинный, выбрав несколько столбцов для плавления.

# %%
# 🧩 Ваш код здесь
import pandas as pd

# %% [markdown]
# 12) Загрузите DataFrame и используйте `pd.get_dummies` для выполнения one-hot кодирования категориального столбца.

# %%
# 🧩 Ваш код здесь
import pandas as pd

# %% [markdown]
# 13) Создайте Series с числовыми данными и используйте `pd.cut` для биннинга данных на 4 равных интервала.

# %%
# 🧩 Ваш код здесь
import pandas as pd
import numpy as np

# %% [markdown]
# 14) Создайте DataFrame и используйте `pd.query()` для фильтрации строк по простому условию (например, `столбец > 10`).

# %%
# 🧩 Ваш код здесь
import pandas as pd

# %% [markdown]
# 15) Создайте DataFrame с категориальным столбцом и преобразуйте его тип данных в `category` с помощью `.astype('category')`.

# %%
# 🧩 Ваш код здесь
import pandas as pd

# %% [markdown]
# 16) Используя `pd.crosstab`, создайте таблицу частот для двух категориальных столбцов в DataFrame.

# %%
# 🧩 Ваш код здесь
import pandas as pd

# %% [markdown]
# 17) Загрузите DataFrame и используйте `pd.pivot` для изменения его структуры, сделав уникальные значения одного столбца новыми столбцами.

# %%
# 🧩 Ваш код здесь
import pandas as pd

# %% [markdown]
# 18) Создайте DataFrame с временными метками и используйте `pd.resample` для агрегации данных по месяцам, вычисляя среднее значение.

# %%
# 🧩 Ваш код здесь
import pandas as pd
from pandas import to_datetime

# %% [markdown]
# 19) Создайте DataFrame и используйте `pd.eval()` для выполнения простой арифметической операции между двумя столбцами (например, `столбец1 + столбец2`).

# %%
# 🧩 Ваш код здесь
import pandas as pd

# %% [markdown]
# 20) Сохраните небольшой DataFrame в формат Parquet с помощью `pd.to_parquet` и затем прочитайте его обратно с помощью `pd.read_parquet`.

# %%
# 🧩 Ваш код здесь
# Требуются зависимости: pyarrow или fastparquet
import pandas as pd

# %% [markdown]
# 🔥 EASY завершён — вы уверенно владете продвинутыми инструментами.

# %% [markdown]
# ## ⚙️ MEDIUM Задания (10)

# %% [markdown]
# 1) Используя `np.einsum`, вычислите сумму произведений двух матриц (матричное умножение). Проверьте результат с помощью `np.dot`.

# %%
# 🧩 Ваш код здесь
import numpy as np
from numpy import dot

# %% [markdown]
# 2) Создайте функцию, которая нормализует одномерный массив (приводит значения к диапазону [0, 1]), затем используйте `np.apply_along_axis` для применения этой функции к каждой колонке двумерного массива.

# %%
# 🧩 Ваш код здесь
import numpy as np

# %% [markdown]
# 3) Сгенерируйте данные для 1000 студентов: `id`, `факультет` (3-4 категории), `баллы_математика`, `баллы_физика`. Используйте `pd.pivot_table` для создания сводной таблицы, показывающей средние баллы по предметам для каждого факультета.

# %%
# 🧩 Ваш код здесь
import pandas as pd
import numpy as np

# %% [markdown]
# 4) Используя `np.random.multivariate_normal`, сгенерируйте 500 двумерных точек, представляющих данные с определенной средней и ковариационной матрицей. (Без визуализации — только генерация данных.)

# %%
# 🧩 Ваш код здесь
import numpy as np
mean = [0, 0]
cov = [[1, 0.5],[0.5, 1]]

# %% [markdown]
# 5) Загрузите DataFrame с данными о транзакциях, содержащими `timestamp` и `amount`. Используйте `pd.resample` с `pd.Grouper` для агрегации данных по неделям и вычисления суммы `amount` и среднего `amount`.

# %%
# 🧩 Ваш код здесь
import pandas as pd
from pandas import to_datetime

# %% [markdown]
# 6) Создайте DataFrame с пропущенными значениями. Используйте `pd.eval()` для создания нового столбца, который является результатом сложной арифметической операции, игнорируя NaN, а затем заполните NaN в исходном DataFrame методом `ffill`.

# %%
# 🧩 Ваш код здесь
import pandas as pd
import numpy as np

# %% [markdown]
# 7) Используя `pd.merge_asof`, объедините два DataFrame: один с данными о ценах акций (`timestamp`, `price`) и другой с данными о новостях (`timestamp`, `headline`), чтобы привязать каждую цену к ближайшей предыдущей новости.

# %%
# 🧩 Ваш код здесь
import pandas as pd
from pandas import to_datetime

# %% [markdown]
# 8) Создайте DataFrame с числовыми данными. Используйте `pd.qcut` для разбиения данных на 5 квантилей и создайте новый столбец с метками квантилей.

# %%
# 🧩 Ваш код здесь
import pandas as pd
import numpy as np

# %% [markdown]
# 9) Реализуйте функцию для вычисления обратной матрицы 3x3 с помощью `np.linalg.inv`. Проверьте, что произведение исходной матрицы на обратную дает единичную матрицу.

# %%
# 🧩 Ваш код здесь
from numpy.linalg import inv
import numpy as np

# %% [markdown]
# 10) Загрузите большой DataFrame. Используйте `astype('category')` для оптимизации использования памяти для одного или нескольких категориальных столбцов. Сравните потребление памяти до и после оптимизации (без кода сравнения, только описание действия).

# %% [markdown]
# ✍️ Ваш ответ здесь (кратко опишите разницу в памяти до/после).

# %% [markdown]
# 🔥 Отлично! Готовы к экспертному уровню.

# %% [markdown]
# ## 🔥 HARD Задания (5)

# %% [markdown]
# 1) Используя `np.einsum`, реализуйте вычисление сингулярного разложения (SVD) для матрицы 4x4. Сравните производительность с `np.linalg.svd` для больших матриц (без кода сравнения, только описание задачи).

# %% [markdown]
# ✍️ Кратко опишите наблюдения о производительности и точности.

# %% [markdown]
# 2) Создайте DataFrame с историческими данными о ценах акций (например, `timestamp`, `open`, `high`, `low`, `close`, `volume`). Используя `pd.resample` и `pd.Grouper`, рассчитайте скользящее среднее (rolling mean) цены закрытия за 30 дней и экспоненциальное скользящее среднее (expanding mean) за весь период для каждого года.

# %%
# 🧩 Ваш код здесь
import pandas as pd
from pandas import to_datetime

# %% [markdown]
# 3) Сгенерируйте данные для симуляции Монте-Карло: 100000 случайных выборок из многомерного нормального распределения (`np.random.multivariate_normal`). Затем, используя `np.apply_along_axis` или `np.vectorize`, рассчитайте для каждой выборки некоторую сложную функцию (например, сумму квадратов элементов, деленную на их произведение).

# %%
# ⚠️ Осторожно с производительностью — начните с меньшего N
# 🧩 Ваш код здесь
import numpy as np

# %% [markdown]
# 4) Используя `pd.merge_ordered` и `pd.merge_asof`, объедините три DataFrame: данные о заказах (`order_id`, `timestamp`, `customer_id`), данные о платежах (`payment_id`, `timestamp`, `order_id`, `amount`) и данные о курсах валют (`currency`, `timestamp`, `rate`). Цель — получить полную картину заказа с учетом курса валют на момент ближайшего платежа и всех последующих платежей.

# %%
# 🧩 Ваш код здесь
import pandas as pd
from pandas import to_datetime

# %% [markdown]
# 5) Разработайте систему для анализа временных рядов, используя `np.gradient` для определения точек изменения тренда и `np.diff` для вычисления скорости изменения. Примените это к DataFrame с данными о температуре за год, чтобы найти дни с наиболее резкими изменениями температуры.

# %%
# 🧩 Ваш код здесь
import numpy as np
import pandas as pd

# %% [markdown]
# 🏁 Поздравляем! Неделя 5 завершена.
#
# 💪 Вы прошли 100% пути к профессиональному уровню NumPy & Pandas!

# %% [markdown]
# # 🏆 Graduation — Поздравляем, Алекс!
#
# Вы завершили путь NumPy & Pandas Killer. Это мощная база для инженерии данных и машинного обучения. Теперь вы владеете инструментами анализа данных, как настоящий инженер ИИ. Впереди — машинное обучение, FastAPI и создание реальных AI‑продуктов!
#
# Что вы освоили:
# - NumPy: массивы, индексация, векторизация, трансформации, статистика, линейная алгебра.
# - Pandas: фильтрации, группировки, агрегации, сводные таблицы, time series, обработка пропусков и текстов.
# - Практика: работа с файлами, категориальные признаки, оптимизация памяти, конвейеры анализа.
#
# Чек‑лист готовности к ML‑этапу:
# - [ ] Уверенно пишу векторизованный код на NumPy.
# - [ ] Свободно работаю с DataFrame: фильтры, группировки, сводные таблицы.
# - [ ] Умею очищать и готовить данные (NaN, дубликаты, типы).
# - [ ] Понимаю основы статистики и могу применять их к реальным данным.
# - [ ] Готов(а) перейти к моделям ML (sklearn) и пайплайнам.
#
# Цитата для вдохновения:
#
# «Мастером становится не тот, кто знает всё, а тот, кто учится каждый день.» — Неизвестный автор
#
# Продолжайте двигаться. Следующая остановка — Machine Learning! 🚀

# %% [markdown]
# # 🎓 Capstone Projects (объединение NumPy + Pandas)
#
# 1. **Анализ данных о продажах:**
# - Загрузите несколько CSV‑файлов (разные месяцы) и объедините их в один DataFrame.
# - Очистите данные: пропуски, дубликаты.
# - Создайте признаки: месяц, день недели, общая стоимость заказа.
# - Сгруппируйте по продуктам и найдите топ‑5 самых продаваемых товаров.
# - Подготовьте данные для визуализации.
#
# 2. **Анализ текстовых данных:**
# - Загрузите датасет с отзывами на фильмы.
# - Очистите текстовые данные: нижний регистр, удалите пунктуацию и стоп‑слова.
# - Создайте признак: длина отзыва.
# - Примитивный сентимент‑анализ (на словаре тональности).
# - Сгруппируйте по фильмам: самые высокие и самые низкие средние рейтинги.
#
# 3. **Финансовый анализ:**
# - Исторические данные о ценах акций нескольких компаний.
# - Дневная доходность, скользящее среднее и std доходности.
# - Корреляция между доходностями разных акций.
# - Простая торговая стратегия и оценка её прибыльности.

# %% [markdown]
# # ✅ Итоговый чек‑лист
#
# - [x] Все 5 недель объединены в один ноутбук.
# - [x] Каждая неделя содержит 20 EASY, 10 MEDIUM, 5 HARD и 5 CONCEPT задач.
# - [x] Сохранена единая структура и читаемость (H1 → H2 → H3).
# - [x] Под каждым заданием есть место для кода/ответа.
# - [x] Добавлены 3 Capstone‑проекта.
# - [x] Добавлена вдохновляющая секция Graduation.
